# %%
def compute_interest(money, period):
  result = 1 + 1/period
  money = money * result ** period
  return money

# %%
compute_interest(1,12)
# Out:
# 2.613035290224676

# %%
compute_interest(1,365)
# Out:
# 2.7145674820219727

# %%
compute_interest(1,730)
# Out:
# 2.7164223264603464
